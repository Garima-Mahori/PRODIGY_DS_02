# %% [markdown]
# # PATIENT HISTORY DATA

# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting seaborn style
sns.set(style="whitegrid")

# %%
# Load CSV file
df = pd.read_csv('Patient_History_data.csv')

# %%
# Display the first 5 rows
df.head()
# Out:
#    Gender     Race StaffEducation  Weight  Height   BMI HeartAttack Stroke  \
# 0  Female    Malay       8.Others    58.2    1.51  25.5          No     No
# 1    Male  Chinese       8.Others    75.9    1.68  26.9          No     No
# 2  Female  Chinese       8.Others    50.3    1.46  23.6         Yes     No
# 3  Female   Indian       8.Others    76.9    1.72  26.0          No     No
# 4    Male   Indian       8.Others    42.1    1.67  15.1          No     No
#
#   Diabetes  HBP  ...    OccupationType    Healthy           Habits Diabetes2  \
# 0       No   No  ...        Unemployed    Healthy  Negative Habits       NaN
# 1       No   No  ...            Others    Healthy  Negative Habits       NaN
# 2       No  Yes  ...   Blue-collar Job  Unhealthy  Negative Habits       NaN
# 3       No   No  ...  White-collar Job  Unhealthy  Negative Habits       NaN
# 4       No   No  ...            Others    Healthy  Negative Habits       NaN
#
# ...

# %%
# Display basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5191 entries, 0 to 5190
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             5191 non-null   object
#  1   Race               5191 non-null   object
#  2   StaffEducation     4964 non-null   object
#  3   Weight             5182 non-null   float64
#  4   Height             5181 non-null   float64
#  5   BMI                5181 non-null   float64
#  6   HeartAttack        5191 non-null   object
#  7   Stroke             5191 non-null   object
#  8   Diabetes           5191 non-null   object
#  9   HBP                5191 non-null   object
#  10  HBldChol           5191 non-null   object
#  11  Smoking            5191 non-null   object
#  12  Exercise           5191 non-null   object
#  13  Stress             5191 non-null   object
#  14  Health             5029 non-null   object
#  15  FruitsVeg          5191 non-null   object
# ...

# %%
# Display summary statistics
df.describe()
# Out:
#             Weight       Height         BMI
# count  5182.000000  5181.000000  5181.00000
# mean     62.856523     1.610992    24.16076
# std      12.619709     0.085232     4.19060
# min      29.300000     1.310000    12.70000
# 25%      53.925000     1.550000    21.40000
# 50%      61.450000     1.610000    23.70000
# 75%      70.300000     1.670000    26.40000
# max     182.000000     1.960000    61.50000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Gender                0
# Race                  0
# StaffEducation        0
# Weight                9
# Height               10
# BMI                  10
# HeartAttack           0
# Stroke                0
# Diabetes              0
# HBP                   0
# HBldChol              0
# Smoking               0
# Exercise              0
# Stress                0
# Health                0
# FruitsVeg             0
# DiabetesFoot          0
# PreferredLanguage     0
# OccupationType        0
# Healthy               0
# Habits                0
# Diabetes2             0
# BloodPressure         0
# Cholesterol           0
# Overweight            0
# AgeGrp                0
# scnZone               0
# healthRisk            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (5181, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5181 entries, 0 to 5190
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             5181 non-null   object
#  1   Race               5181 non-null   object
#  2   StaffEducation     5181 non-null   object
#  3   Weight             5181 non-null   float64
#  4   Height             5181 non-null   float64
#  5   BMI                5181 non-null   float64
#  6   HeartAttack        5181 non-null   object
#  7   Stroke             5181 non-null   object
#  8   Diabetes           5181 non-null   object
#  9   HBP                5181 non-null   object
#  10  HBldChol           5181 non-null   object
#  11  Smoking            5181 non-null   object
#  12  Exercise           5181 non-null   object
#  13  Stress             5181 non-null   object
#  14  Health             5181 non-null   object
#  15  FruitsVeg          5181 non-null   object
# ...

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
# Check data types
print(df.dtypes)
# Out:
# Gender                object
# Race                  object
# StaffEducation        object
# Weight               float64
# Height               float64
# BMI                  float64
# HeartAttack           object
# Stroke                object
# Diabetes              object
# HBP                   object
# HBldChol              object
# Smoking               object
# Exercise              object
# Stress                object
# Health                object
# FruitsVeg             object
# DiabetesFoot          object
# PreferredLanguage     object
# OccupationType        object
# Healthy               object
# Habits                object
# Diabetes2             object
# BloodPressure         object
# Cholesterol           object
# Overweight            object
# AgeGrp                object
# scnZone               object
# healthRisk            object
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['Gender', 'Race', 'StaffEducation', 'Weight', 'Height', 'BMI',
#        'HeartAttack', 'Stroke', 'Diabetes', 'HBP', 'HBldChol', 'Smoking',
#        'Exercise', 'Stress', 'Health', 'FruitsVeg', 'DiabetesFoot',
#        'PreferredLanguage', 'OccupationType', 'Healthy', 'Habits', 'Diabetes2',
#        'BloodPressure', 'Cholesterol', 'Overweight', 'AgeGrp', 'scnZone',
#        'healthRisk'],
#       dtype='object')

# %% [markdown]
# ### Gender

# %%
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### *AGE GROUP*

# %%
ax = sns.countplot(data = df, x = 'AgeGrp')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### Race

# %%
response_counts = df['Race'].value_counts()
labels = response_counts.index
sizes = response_counts.values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Optional: Adjust the size of the figure
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Race ')

# Display the pie chart
plt.show()

# %% [markdown]
# ### Staff Education

# %%
response_counts = df['StaffEducation'].value_counts()
labels = response_counts.index
sizes = response_counts.values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Optional: Adjust the size of the figure
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Education ')

# Display the pie chart
plt.show()

# %% [markdown]
# ### EXERCISE

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'Exercise')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'Exercise')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### DIABETES

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'Diabetes')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'Diabetes')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### High Blood Pressure

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'HBP')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'HBP')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### High Blood Cholestrol

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'HBldChol')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'HBldChol')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### Health Risk

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'healthRisk')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'healthRisk')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### Heart attack

# %%
# Count the occurrences of 'yes' and 'no' in the 'HearAttack' column
response_counts = df['HeartAttack'].value_counts()
labels = response_counts.index
sizes = response_counts.values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Optional: Adjust the size of the figure
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['#66b3ff','#ff9999'])

# Add a title
plt.title('Haert Attack ')

# Display the pie chart
plt.show()

# %% [markdown]
# ### STROKE

# %%
# Count the occurrences of 'yes' and 'no' in the 'HearAttack' column
response_counts = df['Stroke'].value_counts()
labels = response_counts.index
sizes = response_counts.values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Optional: Adjust the size of the figure
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['#66b3ff','#ff9999'])

# Add a title
plt.title('Stroke ')

# Display the pie chart
plt.show()

# %% [markdown]
# ### Over weight

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'Overweight')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'Overweight')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### Fruit Intake

# %%
response_counts = df['FruitsVeg'].value_counts()
labels = response_counts.index
sizes = response_counts.values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Optional: Adjust the size of the figure
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Fruit intake  ')

# Display the pie chart
plt.show()

# %% [markdown]
# ### Smoking

# %%
response_counts = df['Smoking'].value_counts()
labels = response_counts.index
sizes = response_counts.values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Optional: Adjust the size of the figure
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Smoking ')

# Display the pie chart
plt.show()

# %% [markdown]
# ### Healthy

# %%
ax = sns.countplot(data = df, x = 'Gender', hue = 'Healthy')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'AgeGrp', hue = 'Healthy')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### OCCUPATION

# %%
# Group by the 'occupation' column and calculate the mean of the 'weight' column
average_weight_by_occupation = df.groupby('OccupationType')['Weight'].mean().reset_index()

# Display the result
print(average_weight_by_occupation)

# Plot the average weights
plt.figure(figsize=(6, 4))
plt.bar(average_weight_by_occupation['OccupationType'], average_weight_by_occupation['Weight'], color='skyblue')
plt.xlabel('Occupation')
plt.ylabel('Average Weight')
plt.title('Average Weight by Occupation')
plt.xticks(rotation=45)
plt.show()
# Out:
#      OccupationType     Weight
# 0   Blue-collar Job  63.975014
# 1            Others  65.007240
# 2        Unemployed  59.995958
# 3  White-collar Job  65.749945

# %% [markdown]
# # Multivariate Analysis

# %%
numeric_df = df.select_dtypes(include=[float, int])
corr_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
# Scatter matrix using pandas
pd.plotting.scatter_matrix(df, figsize=(12, 8))
plt.show()

# %%
# Pivot the data
pivot_table = df.pivot_table(index='AgeGrp', columns='Gender', aggfunc='size', fill_value=0)

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap='viridis')
plt.title('AGE vs GENDER Data Heatmap')
plt.show()
